# %% [markdown]
# # Zepto Retail EDA
#
# In this notebook I do a simple first check of the raw Zepto dataset before cleaning it.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/zepto.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df['Category'].value_counts()
